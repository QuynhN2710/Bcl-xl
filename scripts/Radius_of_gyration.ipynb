# %%
from Plotting_functions import *

# %%
vivek_data = read_distance_data_file_into_np_array ("/Users/quynhnguyen/kollman/bclx/bclxL_Prot_1_2_CLPC_50mM_CaCl2/analysis/radGyr/vivek_data.dat")

# %%
rerun_data = read_distance_data_file_into_np_array("/Users/quynhnguyen/kollman/bclx/bclxL_Prot_1_2_CLPC_50mM_CaCl2/analysis/radGyr/radGyr_BclxL_Prot_1_2_CLPC_50mM_CaCl2_DisordLoop21-82_Quinn.dat")

# %%
plot_basic(vivek_data[0:2000])

# %%
plot_basic(rerun_data)
