# %% [markdown]
# This notebook is to visualize the density profile data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler

# %%
color_dict = {
    'Carbonyl_TOCL2': 'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_carbonyl_CL_6250to20834_every4.dat',
    'Carbonyl_TOCL2_SN1':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_carbonyl_CL_SN1_6250to20834_every4.dat',
    'Carbonyl_TOCL2_SN2':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_carbonyl_CL_SN2_6250to20834_every4.dat',
    'Phosphate_TOCL2':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_phosphate_CL_6250to20834_every4.dat',
    'Heavy_atoms_TOCL2':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_TOCL2_heavy_atoms_6250to20834_every4.dat',
    'Carbonyl_POPC': 'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_carbonyl_PC_6250to20834_every4.dat',
    'Carbonyl_POPC_SN1':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_carbonyl_PC_SN1_6250to20834_every4.dat',
    'Carbonyl_POPC_SN2':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_carbonyl_PC_SN2_6250to20834_every4.dat',
    'Choline_POPC':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_choline_PC_6250to20834_every4.dat',
    'Glycerol_POPC':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_glycerol_PC_6250to20834_every4.dat',
    'Phosphate_POPC':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_phosphate_PC_6250to20834_every4.dat',
    'Heavy_atoms_POPC':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_POPC_heavy_atoms_6250to20834_every4.dat',
    'CAL':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_nameCAL_6250to20834_every4.dat',
    'CLA':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_nameCLA_6250to20834_every4.dat',
    'water':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_nameOH2_6250to20834_every4.dat'
}

# %%
file_names_CAL_unprotonated = {
    'Carbonyl_TOCL2': 'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_carbonyl_CL_6250to20834_every4.dat',
    'Carbonyl_TOCL2_SN1':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_carbonyl_CL_SN1_6250to20834_every4.dat',
    'Carbonyl_TOCL2_SN2':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_carbonyl_CL_SN2_6250to20834_every4.dat',
    'Phosphate_TOCL2':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_phosphate_CL_6250to20834_every4.dat',
    'Heavy_atoms_TOCL2':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_TOCL2_heavy_atoms_6250to20834_every4.dat',
    'Carbonyl_POPC': 'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_carbonyl_PC_6250to20834_every4.dat',
    'Carbonyl_POPC_SN1':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_carbonyl_PC_SN1_6250to20834_every4.dat',
    'Carbonyl_POPC_SN2':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_carbonyl_PC_SN2_6250to20834_every4.dat',
    'Choline_POPC':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_choline_PC_6250to20834_every4.dat',
    'Glycerol_POPC':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_glycerol_PC_6250to20834_every4.dat',
    'Phosphate_POPC':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_phosphate_PC_6250to20834_every4.dat',
    'Heavy_atoms_POPC':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_POPC_heavy_atoms_6250to20834_every4.dat',
    'CAL':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_nameCAL_6250to20834_every4.dat',
    'CLA':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_nameCLA_6250to20834_every4.dat',
    'water':'ndens_bclxL_Unprot_1_2_CLPC_50mM_CaCl2_nameOH2_6250to20834_every4.dat'
}

base_path = "/Users/quynhnguyen/kollman/bclx/bclxL_Unprot_1_2_CLPC_50mM_CaCl2/analysis/ndens/"
norm_counts={}
for key, value in file_names_CAL_unprotonated.items():
    norm_counts[key]=np.loadtxt(base_path + value, usecols=2, skiprows=1)

# %%
fig = plt.figure(figsize=(12,5))
ax = fig.subplots()
ax.set_prop_cycle(cycler('color', plt.get_cmap('tab10').colors))
for key, value in norm_counts.items():
    if key in ['Carbonyl_POPC', 'Carbonyl_TOCL2', 'CAL', 'water', 'Phosphate_POPC', 'Phosphate_TOCL2']:
        x_values = np.arange(-29.9, 60.1, 0.2)
        ax.plot(x_values,value, label = key)
ax.legend()
#ax.set_xlim(0,30)
ax.set_ylim(0,0.010)
ax.set_title("Density profile Bcl-xl Ca2+")
# Out:
# Text(0.5, 1.0, 'Density profile Bcl-xl Ca2+')

# %%
file_names = {
    'Carbonyl_TOCL2': 'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_carbonyl_CL_6250to20834_every4.dat',
    'Carbonyl_TOCL2_SN1':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_carbonyl_CL_SN1_6250to20834_every4.dat',
    'Carbonyl_TOCL2_SN2':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_carbonyl_CL_SN2_6250to20834_every4.dat',
    'Phosphate_TOCL2':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_phosphate_CL_6250to20834_every4.dat',
    'Heavy_atoms_TOCL2':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_TOCL2_heavy_atoms_6250to20834_every4.dat',
    'Carbonyl_POPC': 'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_carbonyl_PC_6250to20834_every4.dat',
    'Carbonyl_POPC_SN1':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_carbonyl_PC_SN1_6250to20834_every4.dat',
    'Carbonyl_POPC_SN2':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_carbonyl_PC_SN2_6250to20834_every4.dat',
    'Choline_POPC':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_choline_PC_6250to20834_every4.dat',
    'Glycerol_POPC':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_glycerol_PC_6250to20834_every4.dat',
    'Phosphate_POPC':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_phosphate_PC_6250to20834_every4.dat',
    'Heavy_atoms_POPC':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_POPC_heavy_atoms_6250to20834_every4.dat',
    'MG':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_nameMG_6250to20834_every4.dat',
    'CLA':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_nameCLA_6250to20834_every4.dat',
    'water':'ndens_bclxL_Unprot_1_2_CLPC_50mM_MgCl2_nameOH2_6250to20834_every4.dat'
}

base_path = "/Users/quynhnguyen/kollman/bclx/bclxL_Unprot_1_2_CLPC_50mM_MgCl2/analysis/ndens/"
norm_counts_Mg={}
for key, value in file_names.items():
    norm_counts_Mg[key]=np.loadtxt(base_path + value, usecols=2, skiprows=1)

# %%
fig = plt.figure(figsize=(12,5))
ax = fig.subplots()
for key, value in norm_counts_Mg.items():
    if key in ['Carbonyl_POPC', 'Carbonyl_TOCL2', 'MG', 'water', 'Phosphate_POPC', 'Phosphate_TOCL2']:
        x_values = np.arange(-29.9, 60.1, 0.2)
        ax.plot(x_values,value, label = key)
ax.legend()
#ax.set_xlim(0,30)
ax.set_ylim(0,0.010)
ax.set_title("Density profile Bcl-xl Mg2+")
# Out:
# Text(0.5, 1.0, 'Density profile Bcl-xl Mg2+')

# %%
fig=plt.figure()
ax = fig.subplots()
x_values = np.arange(-29.9, 60.1, 0.2)
ax.plot(x_values,norm_counts['CAL'])
ax.plot(x_values,norm_counts_Mg['MG'])
